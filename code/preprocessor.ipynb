# %%
from config import original_data_test_path, original_data_train_path, original_data_png_test_path, original_data_png_train_path, cropped_data_test_path, cropped_data_train_path
from glioma_utils import *

# %%
loop_data_perform_action(convert_jpg_to_png, original_data_test_path, original_data_png_test_path)
loop_data_perform_action(convert_jpg_to_png, original_data_train_path, original_data_png_train_path)
# Out:
# Saved processed image to /p/playground/Glioma-mdc2025/data/original_data_png/test/testing0101.png
# Saved processed image to /p/playground/Glioma-mdc2025/data/original_data_png/test/testing0189.png
# Saved processed image to /p/playground/Glioma-mdc2025/data/original_data_png/test/testing0160.png
# Saved processed image to /p/playground/Glioma-mdc2025/data/original_data_png/test/testing0119.png
# Saved processed image to /p/playground/Glioma-mdc2025/data/original_data_png/test/testing0125.png
# Saved processed image to /p/playground/Glioma-mdc2025/data/original_data_png/test/testing0102.png
# Saved processed image to /p/playground/Glioma-mdc2025/data/original_data_png/test/testing0075.png
# Saved processed image to /p/playground/Glioma-mdc2025/data/original_data_png/test/testing0097.png
# Saved processed image to /p/playground/Glioma-mdc2025/data/original_data_png/test/testing0200.png
# Saved processed image to /p/playground/Glioma-mdc2025/data/original_data_png/test/testing0012.png
# ...

# %%
copy_json_files(original_data_path, original_data_png_path)
# Out:
# Copied /p/playground/Glioma-mdc2025/data/original_data/Glioma_MDC_2025_training/training0506.json to /p/playground/Glioma-mdc2025/data/original_data_png/training0506.json
# Copied /p/playground/Glioma-mdc2025/data/original_data/Glioma_MDC_2025_training/training0200.json to /p/playground/Glioma-mdc2025/data/original_data_png/training0200.json
# Copied /p/playground/Glioma-mdc2025/data/original_data/Glioma_MDC_2025_training/training0982.json to /p/playground/Glioma-mdc2025/data/original_data_png/training0982.json
# Copied /p/playground/Glioma-mdc2025/data/original_data/Glioma_MDC_2025_training/training0747.json to /p/playground/Glioma-mdc2025/data/original_data_png/training0747.json
# Copied /p/playground/Glioma-mdc2025/data/original_data/Glioma_MDC_2025_training/training0491.json to /p/playground/Glioma-mdc2025/data/original_data_png/training0491.json
# ...
